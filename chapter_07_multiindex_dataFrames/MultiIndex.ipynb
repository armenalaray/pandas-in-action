# %%
import pandas as pd

# %%
addresses = [
    ("8809 Flair Square", "Toddside", "IL", "37206"),
    ("9901 Austin Street", "Toddside", "IL", "37206"),
    ("905 Hogan Quarter", "Franklin", "IL", "37206"),
]

#level of the multiindex


row_index = pd.MultiIndex.from_tuples(tuples=addresses, names=["Street", "City", "State", "Zip"])

# %% [markdown]
# Livability of address

# %%
data = [
    ["C-", "B+", "B-", "A"],
    ["D+", "C", "A", "C+"],
    ["A-", "A", "D+", "F"],
]

column_index = pd.MultiIndex.from_tuples(
    [
        ("Culture", "Restaurants"),
        ("Culture", "Museums"),
        ("Services", "Police"),
        ("Services", "Schools"),
    ]
    , names=["Ale", "Maria"]
)

pd.DataFrame(data=data, index=row_index, columns=column_index)
# Out:
# Ale                                         Culture         Services
# Maria                                   Restaurants Museums   Police Schools
# Street             City     State Zip
# 8809 Flair Square  Toddside IL    37206          C-      B+       B-       A
# 9901 Austin Street Toddside IL    37206          D+       C        A      C+
# 905 Hogan Quarter  Franklin IL    37206          A-       A       D+       F

# %%
neighborhoods = pd.read_csv("neighborhoods.csv", index_col=[0,1,2], header=[0,1])

# %%
neighborhoods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 251 entries, ('MO', 'Fisherborough', '244 Tracy View') to ('NE', 'South Kennethmouth', '346 Wallace Pass')
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Culture, Restaurants)  251 non-null    object
#  1   (Culture, Museums)      251 non-null    object
#  2   (Services, Police)      251 non-null    object
#  3   (Services, Schools)     251 non-null    object
# dtypes: object(4)
# memory usage: 27.1+ KB

# %%
neighborhoods.index.names
# Out:
# FrozenList(['State', 'City', 'Street'])

# %%
neighborhoods.columns.names = ["Category", "Subcategory"]

# %%
list(neighborhoods.index.get_level_values(level=2))
# Out:
# ['244 Tracy View',
#  '446 Cynthia Inlet',
#  '432 John Common',
#  '238 Andrew Rue',
#  '877 Walter Neck',
#  '696 Weber Stravenue',
#  '285 Justin Corners',
#  '607 Montoya Harbors',
#  '041 Michael Neck',
#  '550 Gilmore Mountains',
#  '857 Michelle Shoal',
#  '307 Stephens Path',
#  '221 Frederick Plaza',
#  '800 Christopher Haven',
#  '377 Foster View',
#  '281 Austin Crossing',
#  '987 Derek Fall',
#  '542 Jessica Stream',
#  '519 Hill Plaza',
#  '557 Edwards Estates',
#  '398 Erika Lake',
#  '215 Kathleen Flat',
#  '751 Walker Meadows',
#  '693 Avila Pines',
#  '393 Jasmine Hollow',
#  '208 Regina Roads',
#  '695 Amy Ports',
#  '035 Trevor Squares',
#  '369 Victoria Road',
#  '785 Kristen Vista',
#  '417 Simmons Spur',
#  '804 Stephanie Summit',
#  '933 Jennifer Burg',
#  '283 Morales Locks',
#  '798 Joseph Orchard',
#  '008 Mitchell Highway',
#  '665 Cooley Shore',
#  '113 Gordon Ridges',
#  '817 Johnson Street',
#  '502 Taylor Inlet',
#  '154 Alexander Track',
# ...

# %%
neighborhoods.index.get_level_values(level="Street")
# Out:
# Index(['244 Tracy View', '446 Cynthia Inlet', '432 John Common',
#        '238 Andrew Rue', '877 Walter Neck', '696 Weber Stravenue',
#        '285 Justin Corners', '607 Montoya Harbors', '041 Michael Neck',
#        '550 Gilmore Mountains',
#        ...
#        '114 Jones Garden', '320 Jennifer Mission', '692 Hill Glens',
#        '483 Freeman Via', '691 Winters Bridge', '055 Clayton Isle',
#        '601 Richards Road', '385 Robin Harbors', '255 Gonzalez Land',
#        '346 Wallace Pass'],
#       dtype='object', name='Street', length=251)

# %%
neighborhoods.columns
# Out:
# MultiIndex([( 'Culture', 'Restaurants'),
#             ( 'Culture',     'Museums'),
#             ('Services',      'Police'),
#             ('Services',     'Schools')],
#            names=['Category', 'Subcategory'])

# %%
neighborhoods
# Out:
# Category                                       Culture         Services  \
# Subcategory                                Restaurants Museums   Police
# State City               Street
# MO    Fisherborough      244 Tracy View             C+       F       D-
# SD    Port Curtisville   446 Cynthia Inlet          C-       B        B
# WV    Jimenezview        432 John Common             A      A+        F
# AK    Stevenshire        238 Andrew Rue             D-       A       A-
# ND    New Joshuaport     877 Walter Neck            D+      C-        B
# ...                                                ...     ...      ...
# MI    North Matthew      055 Clayton Isle           B-       C        B
# MT    Chadton            601 Richards Road          A-       D       D+
# SC    Diazmouth          385 Robin Harbors           F       D       B-
# VA    Laurentown         255 Gonzalez Land          C+      B-        F
# NE    South Kennethmouth 346 Wallace Pass           C-      B-        A
# ...

# %%
neighborhoods.columns.get_level_values("Subcategory")
# Out:
# Index(['Restaurants', 'Museums', 'Police', 'Schools'], dtype='object', name='Subcategory')

# %%
neighborhoods.nunique()
# Out:
# Category  Subcategory
# Culture   Restaurants    13
#           Museums        13
# Services  Police         13
#           Schools        13
# dtype: int64

# %%
neighborhoods.sort_index(level=[1,2]).head()
# Out:
# Category                                   Culture         Services
# Subcategory                            Restaurants Museums   Police Schools
# State City        Street
# AR    Allisonland 124 Diaz Brooks               C-      A+        F      C+
# IA    Amyburgh    163 Heather Neck               F       D       A+      A-
# GA    Amyburgh    941 Brian Expressway           B       B       D-      C+
# ID    Andrewshire 952 Ellis Drive               C+      A-       C+       A
# VT    Baileyfort  831 Norma Cove                 B      D+       A+      D+

# %%
neighborhoods.sort_index(level=[1,2], ascending=[True,False])
# Out:
# Category                                      Culture         Services
# Subcategory                               Restaurants Museums   Police Schools
# State City          Street
# AR    Allisonland   124 Diaz Brooks                C-      A+        F      C+
# GA    Amyburgh      941 Brian Expressway            B       B       D-      C+
# IA    Amyburgh      163 Heather Neck                F       D       A+      A-
# ID    Andrewshire   952 Ellis Drive                C+      A-       C+       A
# UT    Baileyfort    919 Stewart Hills              D+      C+        A       C
# ...                                               ...     ...      ...     ...
# NC    West Scott    348 Jack Branch                A-      D-       A-       A
# SD    West Scott    139 Hardy Vista                C+      A-       D+      B-
# IN    Wilsonborough 066 Carr Road                  A+      C-        B       F
# NC    Wilsonshire   871 Christopher Vista          B+       B       D+       F
# ...

# %%
neighborhoods.sort_index(axis=1, level=1, ascending=False)
# Out:
# Category                                   Services     Culture Services  \
# Subcategory                                 Schools Restaurants   Police
# State City               Street
# MO    Fisherborough      244 Tracy View          A+          C+       D-
# SD    Port Curtisville   446 Cynthia Inlet       D+          C-        B
# WV    Jimenezview        432 John Common          B           A        F
# AK    Stevenshire        238 Andrew Rue          A-          D-       A-
# ND    New Joshuaport     877 Walter Neck          B          D+        B
# ...                                             ...         ...      ...
# MI    North Matthew      055 Clayton Isle        C+          B-        B
# MT    Chadton            601 Richards Road        D          A-       D+
# SC    Diazmouth          385 Robin Harbors       D+           F       B-
# VA    Laurentown         255 Gonzalez Land       D-          C+        F
# ...

# %%
neighborhoods = neighborhoods.sort_index(ascending=True)

# %%
neighborhoods[[("Services","Schools"),("Culture","Museums"),("Culture","Restaurants")]]
neighborhoods
# Out:
# Category                                      Culture         Services
# Subcategory                               Restaurants Museums   Police Schools
# State City           Street
# AK    Rowlandchester 386 Rebecca Cove              C-      A-       A+       C
#       Scottstad      082 Leblanc Freeway            D      C-        D      B+
#                      114 Jones Garden              D-      D-        D       D
#       Stevenshire    238 Andrew Rue                D-       A       A-      A-
# AL    Clarkland      430 Douglas Mission            A       F       C+      B+
# ...                                               ...     ...      ...     ...
# WY    Lake Nicole    754 Weaver Turnpike            B      D-        B       D
#                      933 Jennifer Burg              C      A+       A-       C
#       Martintown     013 Bell Mills                C-       D       A-      B-
#       Port Jason     624 Faulkner Orchard          A-       F       C+      C+
# ...

# %%
neighborhoods.loc[("CA","Dustinmouth"), ("Services", "Schools")]
# Out:
# Street
# 793 Cynthia Square    A
# Name: (Services, Schools), dtype: object

# %%
neighborhoods.loc["NE":"NH"]
# Out:
# Category                                          Culture         Services  \
# Subcategory                                   Restaurants Museums   Police
# State City               Street
# NE    Barryborough       460 Anna Tunnel               A+      A+        B
#       Shawnchester       802 Cook Cliff                D-      D+        D
#       South Kennethmouth 346 Wallace Pass              C-      B-        A
#       South Nathan       821 Jake Fork                 C+       D       D+
# NH    Courtneyfort       697 Spencer Isle              A+      A+       C+
#       East Deborahberg   271 Ryan Mount                 B       C       D+
#       Ingramton          430 Calvin Underpass          C+      D+        C
#       North Latoya       603 Clark Mount               D-      A-       B+
#       South Tara         559 Michael Glens             C-      C-        F
#
# Category
# Subcategory                                   Schools
# State City               Street
# ...

# %%
neighborhoods.loc[("AK","Scottstad"):("AL","East Connie","943 John Gardens")]
# Out:
# Category                                      Culture         Services
# Subcategory                               Restaurants Museums   Police Schools
# State City           Street
# AK    Scottstad      082 Leblanc Freeway            D      C-        D      B+
#                      114 Jones Garden              D-      D-        D       D
#       Stevenshire    238 Andrew Rue                D-       A       A-      A-
# AL    Clarkland      430 Douglas Mission            A       F       C+      B+
#       East Bobbyside 294 Mitchell Village          C-      A-       B-       F
#       East Connie    943 John Gardens              B+      C-       C+       D

# %%
neighborhoods.loc[("NE","Shawnchester"):("NH")]
# Out:
# Category                                          Culture         Services  \
# Subcategory                                   Restaurants Museums   Police
# State City               Street
# NE    Shawnchester       802 Cook Cliff                D-      D+        D
#       South Kennethmouth 346 Wallace Pass              C-      B-        A
#       South Nathan       821 Jake Fork                 C+       D       D+
# NH    Courtneyfort       697 Spencer Isle              A+      A+       C+
#       East Deborahberg   271 Ryan Mount                 B       C       D+
#       Ingramton          430 Calvin Underpass          C+      D+        C
#       North Latoya       603 Clark Mount               D-      A-       B+
#       South Tara         559 Michael Glens             C-      C-        F
#
# Category
# Subcategory                                   Schools
# State City               Street
# NE    Shawnchester       802 Cook Cliff             A
# ...

# %%
neighborhoods.iloc[[25,30]]
# Out:
# Category                                   Culture         Services
# Subcategory                            Restaurants Museums   Police Schools
# State City             Street
# CT    East Jessicaland 208 Todd Knolls          A+       A       A+      C+
# DC    East Lisaview    910 Sandy Ramp           A-      A+        B       B

# %%
neighborhoods.xs(key="Lake Nicole", level="City")
# Out:
# Category                      Culture         Services
# Subcategory               Restaurants Museums   Police Schools
# State Street
# OR    650 Angela Track              D      C-        D       F
# WY    754 Weaver Turnpike           B      D-        B       D
#       933 Jennifer Burg             C      A+       A-       C

# %%
neighborhoods.xs(axis="columns", key="Museums", level="Subcategory")
# Out:
# Category                                  Culture
# State City           Street
# AK    Rowlandchester 386 Rebecca Cove          A-
#       Scottstad      082 Leblanc Freeway       C-
#                      114 Jones Garden          D-
#       Stevenshire    238 Andrew Rue             A
# AL    Clarkland      430 Douglas Mission        F
# ...                                           ...
# WY    Lake Nicole    754 Weaver Turnpike       D-
#                      933 Jennifer Burg         A+
#       Martintown     013 Bell Mills             D
#       Port Jason     624 Faulkner Orchard       F
#       Reneeshire     717 Patel Square          B+
#
# [251 rows x 1 columns]

# %%
neighborhoods.xs(key=("AK", "238 Andrew Rue"), level=["State", "Street"])
# Out:
# Category        Culture         Services
# Subcategory Restaurants Museums   Police Schools
# City
# Stevenshire          D-       A       A-      A-

# %%
neighborhoods.reorder_levels(order=["City", "State", "Street"])
# Out:
# Category                                      Culture         Services
# Subcategory                               Restaurants Museums   Police Schools
# City           State Street
# Rowlandchester AK    386 Rebecca Cove              C-      A-       A+       C
# Scottstad      AK    082 Leblanc Freeway            D      C-        D      B+
#                      114 Jones Garden              D-      D-        D       D
# Stevenshire    AK    238 Andrew Rue                D-       A       A-      A-
# Clarkland      AL    430 Douglas Mission            A       F       C+      B+
# ...                                               ...     ...      ...     ...
# Lake Nicole    WY    754 Weaver Turnpike            B      D-        B       D
#                      933 Jennifer Burg              C      A+       A-       C
# Martintown     WY    013 Bell Mills                C-       D       A-      B-
# Port Jason     WY    624 Faulkner Orchard          A-       F       C+      C+
# ...

# %%
neighborhoods.reorder_levels([1,0,2])
# Out:
# Category                                      Culture         Services
# Subcategory                               Restaurants Museums   Police Schools
# City           State Street
# Rowlandchester AK    386 Rebecca Cove              C-      A-       A+       C
# Scottstad      AK    082 Leblanc Freeway            D      C-        D      B+
#                      114 Jones Garden              D-      D-        D       D
# Stevenshire    AK    238 Andrew Rue                D-       A       A-      A-
# Clarkland      AL    430 Douglas Mission            A       F       C+      B+
# ...                                               ...     ...      ...     ...
# Lake Nicole    WY    754 Weaver Turnpike            B      D-        B       D
#                      933 Jennifer Burg              C      A+       A-       C
# Martintown     WY    013 Bell Mills                C-       D       A-      B-
# Port Jason     WY    624 Faulkner Orchard          A-       F       C+      C+
# ...

# %%
neighborhoods.reset_index(col_fill="Address" , col_level=1)
# Out:
# Category    Address                                           Culture          \
# Subcategory   State            City                Street Restaurants Museums
# 0                AK  Rowlandchester      386 Rebecca Cove          C-      A-
# 1                AK       Scottstad   082 Leblanc Freeway           D      C-
# 2                AK       Scottstad      114 Jones Garden          D-      D-
# 3                AK     Stevenshire        238 Andrew Rue          D-       A
# 4                AL       Clarkland   430 Douglas Mission           A       F
# ..              ...             ...                   ...         ...     ...
# 246              WY     Lake Nicole   754 Weaver Turnpike           B      D-
# 247              WY     Lake Nicole     933 Jennifer Burg           C      A+
# 248              WY      Martintown        013 Bell Mills          C-       D
# 249              WY      Port Jason  624 Faulkner Orchard          A-       F
# ...

# %%
neighborhoods.reset_index(level=["Street"], col_level="Subcategory", col_fill="Address", drop=True)
# Out:
# Category                 Culture         Services
# Subcategory          Restaurants Museums   Police Schools
# State City
# AK    Rowlandchester          C-      A-       A+       C
#       Scottstad                D      C-        D      B+
#       Scottstad               D-      D-        D       D
#       Stevenshire             D-       A       A-      A-
# AL    Clarkland                A       F       C+      B+
# ...                          ...     ...      ...     ...
# WY    Lake Nicole              B      D-        B       D
#       Lake Nicole              C      A+       A-       C
#       Martintown              C-       D       A-      B-
#       Port Jason              A-       F       C+      C+
#       Reneeshire               B      B+        D       A
#
# [251 rows x 4 columns]

# %%
neighborhoods.reset_index(level=["State","City"], drop=True)
# Out:
# Category                 Culture         Services
# Subcategory          Restaurants Museums   Police Schools
# Street
# 386 Rebecca Cove              C-      A-       A+       C
# 082 Leblanc Freeway            D      C-        D      B+
# 114 Jones Garden              D-      D-        D       D
# 238 Andrew Rue                D-       A       A-      A-
# 430 Douglas Mission            A       F       C+      B+
# ...                          ...     ...      ...     ...
# 754 Weaver Turnpike            B      D-        B       D
# 933 Jennifer Burg              C      A+       A-       C
# 013 Bell Mills                C-       D       A-      B-
# 624 Faulkner Orchard          A-       F       C+      C+
# 717 Patel Square               B      B+        D       A
#
# [251 rows x 4 columns]

# %%
neighborhoods = neighborhoods.reset_index()

# %%
neighborhoods.set_index(keys="City")
# Out:
# Category       State                Street     Culture         Services  \
# Subcategory                                Restaurants Museums   Police
# City
# Rowlandchester    AK      386 Rebecca Cove          C-      A-       A+
# Scottstad         AK   082 Leblanc Freeway           D      C-        D
# Scottstad         AK      114 Jones Garden          D-      D-        D
# Stevenshire       AK        238 Andrew Rue          D-       A       A-
# Clarkland         AL   430 Douglas Mission           A       F       C+
# ...              ...                   ...         ...     ...      ...
# Lake Nicole       WY   754 Weaver Turnpike           B      D-        B
# Lake Nicole       WY     933 Jennifer Burg           C      A+       A-
# Martintown        WY        013 Bell Mills          C-       D       A-
# Port Jason        WY  624 Faulkner Orchard          A-       F       C+
# Reneeshire        WY      717 Patel Square           B      B+        D
#
# Category
# ...

# %%
neighborhoods.set_index(keys=[("Culture","Museums"), "State", "Street", "City"])
# Out:
# Category                                                         Culture  \
# Subcategory                                                  Restaurants
# (Culture, Museums) State Street               City
# A-                 AK    386 Rebecca Cove     Rowlandchester          C-
# C-                 AK    082 Leblanc Freeway  Scottstad                D
# D-                 AK    114 Jones Garden     Scottstad               D-
# A                  AK    238 Andrew Rue       Stevenshire             D-
# F                  AL    430 Douglas Mission  Clarkland                A
# ...                                                                  ...
# D-                 WY    754 Weaver Turnpike  Lake Nicole              B
# A+                 WY    933 Jennifer Burg    Lake Nicole              C
# D                  WY    013 Bell Mills       Martintown              C-
# F                  WY    624 Faulkner Orchard Port Jason              A-
# ...
